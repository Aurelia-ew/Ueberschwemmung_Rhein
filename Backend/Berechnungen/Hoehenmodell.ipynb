# %%
from pathlib import Path
from download import download,unzip

# %%
dest_dir = Path("/Users/aureliaweickgenannt/Documents/Studium/07_Module/04 - FS2026/4040 - Geoprogrammierung_II/08_Heckaton/01_Repository/Ueberschwemmung_Rhein/Backend/Data/Hoehenmodell")

base = "https://data.geo.admin.ch/ch.swisstopo.swissalti3d/"
urls = [base + "swissalti3d_2025_2610-1267/swissalti3d_2025_2610-1267_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2610-1268/swissalti3d_2025_2610-1268_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2610-1269/swissalti3d_2025_2610-1269_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2611-1266/swissalti3d_2025_2611-1266_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2611-1267/swissalti3d_2025_2611-1267_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2611-1268/swissalti3d_2025_2611-1268_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2611-1269/swissalti3d_2025_2611-1269_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2612-1266/swissalti3d_2025_2612-1266_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2612-1267/swissalti3d_2025_2612-1267_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2613-1266/swissalti3d_2025_2613-1266_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2613-1267/swissalti3d_2025_2613-1267_0.5_2056_5728.tif",
        base + "swissalti3d_2025_2613-1268/swissalti3d_2025_2613-1268_0.5_2056_5728.tif",
        ]

for url in urls:
    download(url, str(dest_dir / Path(url).name), overwrite=True)
# Out:
# ...
# 100%|██████████| 16.1M/16.1M [00:00<00:00, 38.7MB/s]
# ...
# 100%|██████████| 15.3M/15.3M [00:00<00:00, 47.9MB/s]
# ...
# 100%|██████████| 14.7M/14.7M [00:00<00:00, 44.6MB/s]
# ...
# 100%|██████████| 16.1M/16.1M [00:00<00:00, 38.6MB/s]
# ...
# 100%|██████████| 15.1M/15.1M [00:00<00:00, 41.6MB/s]
# ...
# 100%|██████████| 14.8M/14.8M [00:00<00:00, 40.8MB/s]
# ...
# 100%|██████████| 15.4M/15.4M [00:00<00:00, 45.6MB/s]
# ...
# 100%|██████████| 15.9M/15.9M [00:00<00:00, 35.2MB/s]
# ...
# 100%|██████████| 14.9M/14.9M [00:00<00:00, 42.1MB/s]
# ...
# 100%|██████████| 16.7M/16.7M [00:00<00:00, 26.2MB/s]
# ...
# 100%|██████████| 15.0M/15.0M [00:00<00:00, 26.5MB/s]
# ...
# 100%|██████████| 15.5M/15.5M [00:00<00:00, 39.3MB/s]

# %%
from pathlib import Path
from osgeo import gdal

gdal.BuildVRT(
    "../Data/Hoehenmodell/Hoehenmodell.vrt",
    [
        "../Data/Hoehenmodell/swissalti3d_2025_2610-1267_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2610-1268_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2610-1269_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2611-1266_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2611-1267_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2611-1268_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2611-1269_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2612-1266_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2612-1267_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2613-1266_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2613-1267_0.5_2056_5728.tif",
        "../Data/Hoehenmodell/swissalti3d_2025_2613-1268_0.5_2056_5728.tif",

    ],
)

print(gdal.Info("../Data/Hoehenmodell/Hoehenmodell.vrt"))
# Out:
# Driver: VRT/Virtual Raster
# Files: ../Data/Hoehenmodell/Hoehenmodell.vrt
#        ../Data/Hoehenmodell/swissalti3d_2025_2610-1267_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2610-1268_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2610-1269_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2611-1266_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2611-1267_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2611-1268_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2611-1269_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2612-1266_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2612-1267_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2613-1266_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2613-1267_0.5_2056_5728.tif
#        ../Data/Hoehenmodell/swissalti3d_2025_2613-1268_0.5_2056_5728.tif
# Size is 8000, 8000
# ...

# %%
import rasterio
import matplotlib.pyplot as plt

pfad= "../Data/Hoehenmodell/swissalti3d_2025_2610-1267_0.5_2056_5728.tif"
# GeoTIFF öffnen
with rasterio.open(pfad) as src:

    # Erstes Band lesen (Höhenwerte)
    hoehen = src.read(1)

    # Metadaten
    print(src.crs)        # Koordinatensystem
    print(src.transform)  # Georeferenzierung
    print(src.bounds)     # Ausdehnung

print(hoehen.shape)
# Out:
# EPSG:2056
# | 0.50, 0.00, 2610000.00|
# | 0.00,-0.50, 1268000.00|
# | 0.00, 0.00, 1.00|
# BoundingBox(left=2610000.0, bottom=1267000.0, right=2611000.0, top=1268000.0)
# (2000, 2000)
